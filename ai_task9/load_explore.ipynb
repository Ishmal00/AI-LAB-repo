# %% [markdown]
# <div class="alert alert-block alert-info">
# <h1><b>Lab 9 Task </b></h1>
# <div class="alert alert-block alert-danger">
# <h2>Submitted by : Ishmal Nadeem(101)</h2>
# </div>
# </div>
# <b>1. Choose any Dataset (csv/json) from Kaggle and apply the following:
# • Data Loading / Reading
# • Data Exploration </b>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3><b>Data Loading</b></h3>
# <div class="alert alert-block alert-danger">
# <h4>1. Read CSV: </h4>
# </div>
# </div>

# %%
import pandas as pd 
df = pd.read_csv('top_restaurants.csv')
df
# Out:
#              Restaurant_Name             City    Country  \
# 0        Osteria Francescana           Modena      Italy
# 1                     Odette        Singapore  Singapore
# 2         The French Laundry       Yountville        USA
# 3                     Arpège            Paris     France
# 4                    Mirazur           Menton     France
# 5                   Frantzén        Stockholm     Sweden
# 6               Le Bernardin         New York        USA
# 7               Piazza Duomo             Alba      Italy
# 8                      Arzak    San Sebastián      Spain
# 9              Atelier Crenn    San Francisco        USA
# 10                      Benu    San Francisco        USA
# 11              Alléno Paris            Paris     France
# 12                La Pergola             Rome      Italy
# 13            Quique Dacosta            Dénia      Spain
# 14                L'Astrance            Paris     France
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2. Print Top 5 rows of dataset: </b>
# </div>

# %%
df.head(5)
# Out:
#        Restaurant_Name        City    Country          Cuisine_Type  \
# 0  Osteria Francescana      Modena      Italy  Italian Contemporary
# 1               Odette   Singapore  Singapore   French Contemporary
# 2   The French Laundry  Yountville        USA                French
# 3               Arpège       Paris     France     French Vegetarian
# 4              Mirazur      Menton     France         Mediterranean
#
#    Michelin_Stars  Average_Price_USD             Chef  Established_Year  \
# 0               3                320  Massimo Bottura              1995
# 1               3                320     Julien Royer              2008
# 2               3                390    Thomas Keller              1994
# 3               3                425    Alain Passard              1986
# 4               3                350  Mauro Colagreco              1991
#
#    Seating_Capacity  Rating           Signature_Dish  Years_Operating  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3. Print Bottom 5 rows of dataset:  </b>
# </div>

# %%
df.tail(5)
# Out:
#              Restaurant_Name             City   Country  \
# 45                    Boragó         Santiago     Chile
# 46  Blue Hill at Stone Barns  Pocantico Hills       USA
# 47              White Rabbit           Moscow    Russia
# 48                       Leo           Bogotá  Colombia
# 49                    Lyle's           London        UK
#
#               Cuisine_Type  Michelin_Stars  Average_Price_USD  \
# 45    Chilean Contemporary               0                145
# 46           Farm-to-Table               0                285
# 47    Contemporary Russian               0                220
# 48  Colombian Contemporary               0                125
# 49    British Contemporary               0                 85
#
#                Chef  Established_Year  Seating_Capacity  Rating  \
# 45   Rodolfo Guzmán              2006                40     4.6
# 46       Dan Barber              2004                70     4.6
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4. Print Number of Rows and Columns in dataset:   </b>
# </div>

# %%
# df.shape # (rows, columns)
print('rows: ', df.shape[0])  # [0] means x-axis
print('columns: ', df.shape[1]) # [1] means x-axis
# Out:
# rows:  50
# columns:  15

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5. Print/Determine all the null columns in dataset: </b>
# </div>

# %%
df.isnull().sum()
# Out:
# Restaurant_Name      0
# City                 0
# Country              0
# Cuisine_Type         0
# Michelin_Stars       0
# Average_Price_USD    0
# Chef                 0
# Established_Year     0
# Seating_Capacity     0
# Rating               0
# Signature_Dish       0
# Years_Operating      0
# Price_Category       0
# Star_Category        0
# Continent            0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>6. Print datatype of each column:  </b>
# </div>

# %%
df.dtypes
# Out:
# Restaurant_Name       object
# City                  object
# Country               object
# Cuisine_Type          object
# Michelin_Stars         int64
# Average_Price_USD      int64
# Chef                  object
# Established_Year       int64
# Seating_Capacity       int64
# Rating               float64
# Signature_Dish        object
# Years_Operating        int64
# Price_Category        object
# Star_Category         object
# Continent             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_Name    50 non-null     object
#  1   City               50 non-null     object
#  2   Country            50 non-null     object
#  3   Cuisine_Type       50 non-null     object
#  4   Michelin_Stars     50 non-null     int64
#  5   Average_Price_USD  50 non-null     int64
#  6   Chef               50 non-null     object
#  7   Established_Year   50 non-null     int64
#  8   Seating_Capacity   50 non-null     int64
#  9   Rating             50 non-null     float64
#  10  Signature_Dish     50 non-null     object
#  11  Years_Operating    50 non-null     int64
#  12  Price_Category     50 non-null     object
#  13  Star_Category      50 non-null     object
#  14  Continent          50 non-null     object
# dtypes: float64(1), int64(5), object(9)
# ...

# %%
df.describe()
# Out:
#        Michelin_Stars  Average_Price_USD  Established_Year  Seating_Capacity  \
# count       50.000000           50.00000         50.000000          50.00000
# mean         1.920000          281.06000       2001.780000          41.96000
# std          1.192494          103.57811         17.962876          14.69966
# min          0.000000           85.00000       1897.000000          10.00000
# 25%          1.000000          212.50000       1998.500000          30.50000
# 50%          2.000000          282.50000       2006.500000          45.00000
# 75%          3.000000          323.75000       2010.750000          50.00000
# max          3.000000          570.00000       2017.000000          80.00000
#
#           Rating  Years_Operating
# count  50.000000        50.000000
# mean    4.702000        23.220000
# std     0.109712        17.962876
# min     4.500000         8.000000
# 25%     4.600000        14.250000
# 50%     4.700000        18.500000
# ...

# %%
df.count()
# df.count(1) # 1 wala column dikhaye ga
# Out:
# Restaurant_Name      50
# City                 50
# Country              50
# Cuisine_Type         50
# Michelin_Stars       50
# Average_Price_USD    50
# Chef                 50
# Established_Year     50
# Seating_Capacity     50
# Rating               50
# Signature_Dish       50
# Years_Operating      50
# Price_Category       50
# Star_Category        50
# Continent            50
# dtype: int64

# %%
df['Rating'].unique()
# Out:
# array([4.9, 4.8, 4.7, 4.6, 4.5])

# %%
df.nunique()
# Out:
# Restaurant_Name      50
# City                 34
# Country              19
# Cuisine_Type         36
# Michelin_Stars        4
# Average_Price_USD    38
# Chef                 50
# Established_Year     26
# Seating_Capacity     26
# Rating                5
# Signature_Dish       50
# Years_Operating      26
# Price_Category        4
# Star_Category         4
# Continent             4
# dtype: int64

# %%
df['Cuisine_Type'].value_counts()
# Out:
# Cuisine_Type
# French Contemporary       4
# Mediterranean             3
# Contemporary American     3
# French                    2
# Asian Fusion              2
# New Nordic                2
# Basque                    2
# Italian                   2
# Contemporary Mexican      2
# British Contemporary      2
# French Vegetarian         1
# Italian Contemporary      1
# French Haute Cuisine      1
# Contemporary French       1
# Contemporary Catalan      1
# Italian Haute Cuisine     1
# Molecular Gastronomy      1
# Avant-garde               1
# French Seafood            1
# Nordic Contemporary       1
# Japanese-Californian      1
# Japanese Kaiseki          1
# Basque Experimental       1
# Japanese Innovative       1
# Experimental              1
# Basque Grill              1
# Modern BBQ                1
# Austrian Contemporary     1
# Contemporary Peruvian     1
# Nikkei                    1
# Progressive Indian        1
# Contemporary German       1
# ...

# %%
for i in df['Signature_Dish'].unique():
    print(i)
# Out:
# Five Ages of Parmigiano
# Hokkaido Sea Urchin
# Oysters and Pearls
# Heirloom Tomatoes
# Salt Crusted Beetroot
# Reindeer Moss
# Barely Cooked Salmon
# Fassona Beef
# Red Mullet
# Kir Breton Royale
# Thousand Year Quail Egg
# Cabbage & Caviar
# Fagottelli
# Rice with Seafood
# Lobster Ravioli
# El Mundo
# Radish & Roses
# Lavender Honey Duck
# Black Truffle Explosion
# Risotto
# Roasted Egg
# 20 Textures
# Fermented Vegetables
# Dentucky Fried Chicken
# Whole Roasted Chicken
# Char Sui Duck
# Satoyama Cuisine
# Ayu Fish
# Char with Hay
# Shaved Foie Gras
# Octopus
# Langoustine
# Panchino
# Edible Stones
# Dehydrated Malt Flatbread
# Grilled Turbot
# Buttermilk Chicken
# Sanger
# Celeriac Toast
# Piranha & Coca
# Causa Nikkei
# Mole Madre
# Lick It Up
# Esquites
# Massaman Curry
# Sea Urchin
# Root Vegetables
# King Crab
# Amazon Ants
# Pork Chop

# %%
for i in df['Chef'].unique():
    print(i)
# Out:
# Massimo Bottura
# Julien Royer
# Thomas Keller
# Alain Passard
# Mauro Colagreco
# Björn Frantzén
# Eric Ripert
# Enrico Crippa
# Juan Mari Arzak
# Dominique Crenn
# Corey Lee
# Yannick Alléno
# Heinz Beck
# Quique Dacosta
# Pascal Barbot
# Joan Roca
# Rasmus Kofoed
# Daniel Humm
# Grant Achatz
# Massimiliano Alajmo
# Eneko Atxa
# Paul Pairet
# René Redzepi
# Zaiyu Hasegawa
# Kyle & Katina Connaughton
# Tim Raue
# Yoshihiro Narisawa
# Hiroyasu Kawate
# Heinz Reitbauer
# Sean Gray
# André Chiang
# Richard Ekkebus
# Oriol Castro
# Andoni Luis Aduriz
# Rasmus Munk
# Victor Arguinzoniz
# Isaac McHale
# Dave Pynt
# Bertrand Grébaut
# Virgilio Martínez
# Mitsuharu Tsumura
# Enrique Olvera
# Gaggan Anand
# Jorge Vallejo
# Thomas & Mathias Sühring
# Rodolfo Guzmán
# Dan Barber
# Vladimir Mukhin
# Leonor Espinosa
# James Lowe
