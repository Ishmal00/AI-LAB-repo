# %% [markdown]
# ## **AI-LAB 6**
# ### **Submitted by : Ishmal Nadeem**
# ### **Roll No: 101**

# %% [markdown]
# ### ***1. BFS with Queue***

# %%
class GraphTraversal:
    
    def __init__(self, graph):
        self.graph = graph
        self.path = []

    def bfs_with_queue(self, start, goal):
        queue = [start]
        self.path = []
        print(f"Starting BFS with Queue from: {start}, and the Goal is : {goal}")

        while queue:
            current = queue.pop(0)
            print(f"Dequeued: {current}, Current Path: {self.path}")
            self.path.append(current)

            if current == goal:
                print(f"Goal {goal} found. Final Path: {self.path}")
                return self.path

            print(f"Expanding {current}, adding children: {self.graph[current]}")
            queue.extend(self.graph[current])
            print(f"Queue now: {queue}")

        print(f"Goal {goal} not found.")
        print('Final output: ', self.path)

        return False




graph_data = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': ['G', 'H'],
    'E': [],
    'F': ['I', 'K'],
    'G': [],
    'H': ['L'],
    'I': [],
    'K': ['M'],
    'L': [],
    'M': []
}

traversal = GraphTraversal(graph_data)

start_node = 'A'
goal_node = input("Enter the goal state: ")

print("\nBFS With Queue (Iterative) ")
result = traversal.bfs_with_queue(start_node, goal_node)
# Out:
# BFS With Queue (Iterative)
# Starting BFS with Queue from: A, and the Goal is : F
# Dequeued: A, Current Path: []
# Expanding A, adding children: ['B', 'C']
# Queue now: ['B', 'C']
# Dequeued: B, Current Path: ['A']
# Expanding B, adding children: ['D', 'E']
# Queue now: ['C', 'D', 'E']
# Dequeued: C, Current Path: ['A', 'B']
# Expanding C, adding children: ['F']
# Queue now: ['D', 'E', 'F']
# Dequeued: D, Current Path: ['A', 'B', 'C']
# Expanding D, adding children: ['G', 'H']
# Queue now: ['E', 'F', 'G', 'H']
# Dequeued: E, Current Path: ['A', 'B', 'C', 'D']
# Expanding E, adding children: []
# Queue now: ['F', 'G', 'H']
# Dequeued: F, Current Path: ['A', 'B', 'C', 'D', 'E']
# Goal F found. Final Path: ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# ### ***1. BFS without Queue***

# %%
class GraphTraversal:
    def __init__(self, graph):
        self.graph = graph
        self.path = []

        
    def bfs_no_queue(self, levels, goal):
            
                print(f"Exploring Level: {levels}, Current Path: {self.path}")
                if not levels:
                    print(f"No more levels to explore. Goal {goal} not found.")
                    return False

                next_level = []
                for node in levels:
                    print(f"Visiting: {node}")
                    self.path.append(node)

                    if node == goal:
                        print(f"Goal {goal} found. Final Path: {self.path}")
                        return self.path

                    print(f"Adding children of {node}: {self.graph[node]}")
                    next_level.extend(self.graph[node])

                return self.bfs_no_queue(next_level, goal)


graph_data = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': ['G', 'H'],
    'E': [],
    'F': ['I', 'K'],
    'G': [],
    'H': ['L'],
    'I': [],
    'K': ['M'],
    'L': [],
    'M': []
}

traversal = GraphTraversal(graph_data)


start_node = 'A'
goal_node = input("Enter the goal state: ")
print("\nBFS Without Queue (Recursive Levels)")
traversal.path = []
result = traversal.bfs_no_queue([start_node], goal_node)
# Out:
# BFS Without Queue (Recursive Levels)
# Exploring Level: ['A'], Current Path: []
# Visiting: A
# Adding children of A: ['B', 'C']
# Exploring Level: ['B', 'C'], Current Path: ['A']
# Visiting: B
# Adding children of B: ['D', 'E']
# Visiting: C
# Adding children of C: ['F']
# Exploring Level: ['D', 'E', 'F'], Current Path: ['A', 'B', 'C']
# Visiting: D
# Adding children of D: ['G', 'H']
# Visiting: E
# Adding children of E: []
# Visiting: F
# Goal F found. Final Path: ['A', 'B', 'C', 'D', 'E', 'F']
